# %% [markdown]
# <a href="https://colab.research.google.com/github/AshrafAbdRahman/Data-Science-Capstone/blob/main/blooddonor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **<h1> 🅱️l🅾️🅾️d D🅾️n🅰️ti🅾️n 💉🩸 </h1>**

# %% [markdown]
# GROUP MEMBER
#
# 1. MUHAMMAD BAKHTIAR BIN YUSOF
# 2. MUHAMMAD AKRAM BIN MOHD NAWAWI
# 3. MUHAMMAD ASHRAF BIN ABD RAHMAN

# %% [markdown]
# Please Download the [Data](
#   https://drive.google.com/file/d/1nSgadPusbAqyVxiEN7xmwDRCdxz8dyJN/view?usp=drive_link)

# %% [markdown]
# **<h3>Problem Statement:</h3>**
#
# Challenges in Sustaining a Stable and Sufficient Blood Supply in Malaysia

# %% [markdown]
# **<h3>Literature Review:</h3>**
#
# *Blood donation is a critical healthcare initiative in Malaysia, ensuring a steady supply for medical emergencies, surgeries, and chronic illnesses. The government has introduced various strategies, including awareness campaigns, mobile donation units, and incentives to attract volunteer donors. However, challenges like public misconceptions, donor retention issues, and disruptions due to external factors (e.g., the COVID-19 pandemic) continue to impact donation rates. Addressing these challenges through education, improved donor engagement, and technological advancements is essential for sustaining Malaysia’s blood supply*

# %% [markdown]
# **<h3>Data Sources:</h3>**
#
# ![image.png](data:image/png;base64,...)
#
# **Ministery of Health [(MOH)](https://github.com/MoH-Malaysia/data-darah-public)**

# %% [markdown]
# **<H2>Exploratory Data Analysis (EDA)</H2>**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("blood_data.csv")
df
# Out:
#            date     state  daily  blood_a  blood_b  blood_o  blood_ab  \
# 0      1/1/2020  Malaysia   1646      419      444      663       120
# 1      2/1/2020  Malaysia    642      161      151      294        36
# 2      3/1/2020  Malaysia    787      196      209      338        44
# 3      4/1/2020  Malaysia   1301      342      347      529        83
# 4      5/1/2020  Malaysia   2345      604      609     1001       131
# ...         ...       ...    ...      ...      ...      ...       ...
# 1857  31/1/2025  Malaysia    886      212      232      382        60
# 1858   1/2/2025  Malaysia   1551      368      426      666        91
# 1859   2/2/2025  Malaysia   1796      428      474      770       124
# 1860   3/2/2025  Malaysia    902      207      239      405        51
# 1861   4/2/2025  Malaysia   1420      343      389      641        47
#
#       type_apheresis_platelet  type_apheresis_plasma  type_other  \
# ...

# %%
df.head()
# Out:
#        date     state  daily  blood_a  blood_b  blood_o  blood_ab  \
# 0  1/1/2020  Malaysia   1646      419      444      663       120
# 1  2/1/2020  Malaysia    642      161      151      294        36
# 2  3/1/2020  Malaysia    787      196      209      338        44
# 3  4/1/2020  Malaysia   1301      342      347      529        83
# 4  5/1/2020  Malaysia   2345      604      609     1001       131
#
#    type_apheresis_platelet  type_apheresis_plasma  type_other  \
# 0                       14                      7          49
# 1                       15                      3           1
# 2                       21                     10           0
# 3                       21                      9           1
# 4                        1                      0           8
#
#    social_civilian  social_student  social_policearmy  donations_new  \
# 0             1367             253                 26            350
# ...

# %%
df.tail()
# Out:
#            date     state  daily  blood_a  blood_b  blood_o  blood_ab  \
# 1857  31/1/2025  Malaysia    886      212      232      382        60
# 1858   1/2/2025  Malaysia   1551      368      426      666        91
# 1859   2/2/2025  Malaysia   1796      428      474      770       124
# 1860   3/2/2025  Malaysia    902      207      239      405        51
# 1861   4/2/2025  Malaysia   1420      343      389      641        47
#
#       type_apheresis_platelet  type_apheresis_plasma  type_other  \
# 1857                       26                      1           0
# 1858                       14                      5           0
# 1859                        4                      0           0
# 1860                       26                      7           0
# 1861                       24                      2           0
#
#       social_civilian  social_student  social_policearmy  donations_new  \
# 1857              810              69                  7             81
# ...

# %%
df.columns
# Out:
# Index(['date', 'state', 'daily', 'blood_a', 'blood_b', 'blood_o', 'blood_ab',
#        'type_apheresis_platelet', 'type_apheresis_plasma', 'type_other',
#        'social_civilian', 'social_student', 'social_policearmy',
#        'donations_new', 'donations_regular', 'donations_irregular'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1862 entries, 0 to 1861
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     1862 non-null   object
#  1   state                    1862 non-null   object
#  2   daily                    1862 non-null   int64
#  3   blood_a                  1862 non-null   int64
#  4   blood_b                  1862 non-null   int64
#  5   blood_o                  1862 non-null   int64
#  6   blood_ab                 1862 non-null   int64
#  7   type_apheresis_platelet  1862 non-null   int64
#  8   type_apheresis_plasma    1862 non-null   int64
#  9   type_other               1862 non-null   int64
#  10  social_civilian          1862 non-null   int64
#  11  social_student           1862 non-null   int64
#  12  social_policearmy        1862 non-null   int64
#  13  donations_new            1862 non-null   int64
# ...

# %%
df.describe()
# Out:
#              daily      blood_a      blood_b      blood_o     blood_ab  \
# count  1862.000000  1862.000000  1862.000000  1862.000000  1862.000000
# mean   1489.146617   367.156284   403.080559   634.208915    84.645005
# std     663.819922   168.629870   176.596928   286.170289    38.341619
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1001.000000   242.000000   269.250000   427.000000    57.000000
# 50%    1336.000000   326.000000   368.000000   564.500000    77.000000
# 75%    1788.750000   441.000000   489.000000   758.750000   106.000000
# max    4047.000000  1066.000000  1106.000000  1747.000000   234.000000
#
#        type_apheresis_platelet  type_apheresis_plasma   type_other  \
# count              1862.000000            1862.000000  1862.000000
# mean                 17.247046               6.868421     1.055317
# std                   8.197599               5.415997     5.633023
# ...

# %%
df.isnull().sum()
# Out:
# date                       0
# state                      0
# daily                      0
# blood_a                    0
# blood_b                    0
# blood_o                    0
# blood_ab                   0
# type_apheresis_platelet    0
# type_apheresis_plasma      0
# type_other                 0
# social_civilian            0
# social_student             0
# social_policearmy          0
# donations_new              0
# donations_regular          0
# donations_irregular        0
# dtype: int64

# %%
df.isna().sum()
# Out:
# date                       0
# state                      0
# daily                      0
# blood_a                    0
# blood_b                    0
# blood_o                    0
# blood_ab                   0
# type_apheresis_platelet    0
# type_apheresis_plasma      0
# type_other                 0
# social_civilian            0
# social_student             0
# social_policearmy          0
# donations_new              0
# donations_regular          0
# donations_irregular        0
# dtype: int64

# %% [markdown]
# **<h2>Data Cleaning</h2>**

# %%
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')
df
# Out:
#            date     state  daily  blood_a  blood_b  blood_o  blood_ab  \
# 0    2020-01-01  Malaysia   1646      419      444      663       120
# 1    2020-01-02  Malaysia    642      161      151      294        36
# 2    2020-01-03  Malaysia    787      196      209      338        44
# 3    2020-01-04  Malaysia   1301      342      347      529        83
# 4    2020-01-05  Malaysia   2345      604      609     1001       131
# ...         ...       ...    ...      ...      ...      ...       ...
# 1857 2025-01-31  Malaysia    886      212      232      382        60
# 1858 2025-02-01  Malaysia   1551      368      426      666        91
# 1859 2025-02-02  Malaysia   1796      428      474      770       124
# 1860 2025-02-03  Malaysia    902      207      239      405        51
# 1861 2025-02-04  Malaysia   1420      343      389      641        47
#
#       type_apheresis_platelet  type_apheresis_plasma  type_other  \
# ...

# %%
df.loc[:, 'days'] = pd.to_datetime(df['date']).dt.day_name()
df
# Out:
#            date     state  daily  blood_a  blood_b  blood_o  blood_ab  \
# 0    2020-01-01  Malaysia   1646      419      444      663       120
# 1    2020-01-02  Malaysia    642      161      151      294        36
# 2    2020-01-03  Malaysia    787      196      209      338        44
# 3    2020-01-04  Malaysia   1301      342      347      529        83
# 4    2020-01-05  Malaysia   2345      604      609     1001       131
# ...         ...       ...    ...      ...      ...      ...       ...
# 1857 2025-01-31  Malaysia    886      212      232      382        60
# 1858 2025-02-01  Malaysia   1551      368      426      666        91
# 1859 2025-02-02  Malaysia   1796      428      474      770       124
# 1860 2025-02-03  Malaysia    902      207      239      405        51
# 1861 2025-02-04  Malaysia   1420      343      389      641        47
#
#       type_apheresis_platelet  type_apheresis_plasma  type_other  \
# ...

# %%
df['year'] = df['date'].dt.year
df
# Out:
#            date     state  daily  blood_a  blood_b  blood_o  blood_ab  \
# 0    2020-01-01  Malaysia   1646      419      444      663       120
# 1    2020-01-02  Malaysia    642      161      151      294        36
# 2    2020-01-03  Malaysia    787      196      209      338        44
# 3    2020-01-04  Malaysia   1301      342      347      529        83
# 4    2020-01-05  Malaysia   2345      604      609     1001       131
# ...         ...       ...    ...      ...      ...      ...       ...
# 1857 2025-01-31  Malaysia    886      212      232      382        60
# 1858 2025-02-01  Malaysia   1551      368      426      666        91
# 1859 2025-02-02  Malaysia   1796      428      474      770       124
# 1860 2025-02-03  Malaysia    902      207      239      405        51
# 1861 2025-02-04  Malaysia   1420      343      389      641        47
#
#       type_apheresis_platelet  type_apheresis_plasma  type_other  \
# ...

# %%
df = df.loc[(df['date'].dt.year >= 2020) & (df['date'].dt.year <= 2024)]
df
# Out:
#            date     state  daily  blood_a  blood_b  blood_o  blood_ab  \
# 0    2020-01-01  Malaysia   1646      419      444      663       120
# 1    2020-01-02  Malaysia    642      161      151      294        36
# 2    2020-01-03  Malaysia    787      196      209      338        44
# 3    2020-01-04  Malaysia   1301      342      347      529        83
# 4    2020-01-05  Malaysia   2345      604      609     1001       131
# ...         ...       ...    ...      ...      ...      ...       ...
# 1822 2024-12-27  Malaysia   1023      261      272      440        50
# 1823 2024-12-28  Malaysia   1798      475      501      724        98
# 1824 2024-12-29  Malaysia   2748      686      717     1192       153
# 1825 2024-12-30  Malaysia   1089      285      280      459        65
# 1826 2024-12-31  Malaysia   1702      414      468      731        89
#
#       type_apheresis_platelet  type_apheresis_plasma  type_other  \
# ...

# %%
df = df.loc[:, ~df.columns.isin(['type_apheresis_platelet', 'type_apheresis_plasma',
                                  'type_other', 'social_civilian', 'social_student',
                                  'social_policearmy', 'state'])]
df
# Out:
#            date  daily  blood_a  blood_b  blood_o  blood_ab  donations_new  \
# 0    2020-01-01   1646      419      444      663       120            350
# 1    2020-01-02    642      161      151      294        36            111
# 2    2020-01-03    787      196      209      338        44            149
# 3    2020-01-04   1301      342      347      529        83            274
# 4    2020-01-05   2345      604      609     1001       131            487
# ...         ...    ...      ...      ...      ...       ...            ...
# 1822 2024-12-27   1023      261      272      440        50            129
# 1823 2024-12-28   1798      475      501      724        98            248
# 1824 2024-12-29   2748      686      717     1192       153            295
# 1825 2024-12-30   1089      285      280      459        65            189
# 1826 2024-12-31   1702      414      468      731        89            336
#
#       donations_regular  donations_irregular       days  year
# ...

# %%
# df.loc[:, ['daily', 'blood_a', 'blood_b', 'blood_o', 'blood_ab',
#            'donations_new', 'donations_regular', 'donations_irregular', 'year']] = \
# df.loc[:, ['daily', 'blood_a', 'blood_b', 'blood_o', 'blood_ab',
#            'donations_new', 'donations_regular', 'donations_irregular', 'year']].astype('int16')
# df.info()
df[['daily', 'blood_a', 'blood_b', 'blood_o', 'blood_ab',
           'donations_new', 'donations_regular', 'donations_irregular', 'year']] = df[['daily', 'blood_a', 'blood_b', 'blood_o', 'blood_ab',
           'donations_new', 'donations_regular', 'donations_irregular', 'year']].astype('int16')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1827 entries, 0 to 1826
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date                 1827 non-null   datetime64[ns]
#  1   daily                1827 non-null   int16
#  2   blood_a              1827 non-null   int16
#  3   blood_b              1827 non-null   int16
#  4   blood_o              1827 non-null   int16
#  5   blood_ab             1827 non-null   int16
#  6   donations_new        1827 non-null   int16
#  7   donations_regular    1827 non-null   int16
#  8   donations_irregular  1827 non-null   int16
#  9   days                 1827 non-null   object
#  10  year                 1827 non-null   int16
# dtypes: datetime64[ns](1), int16(9), object(1)
# memory usage: 74.9+ KB
# <ipython-input-16-e961916f2ae0>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **<h2>Data Visualization</h2>**

# %%
# df = df.copy()
blood_types = ['blood_a', 'blood_b', 'blood_o', 'blood_ab']

years = df['year'].unique()
x = np.arange(len(blood_types))

plt.figure(figsize=(14, 9))

colors = ['blue', 'red', 'green', 'purple', 'orange', 'brown']

for i, year in enumerate(sorted(years)):
    df_year = df[df['year'] == year]
    avg_blood_donations = [df_year[blood].sum() for blood in blood_types]

    plt.bar(x + (i * 0.15), avg_blood_donations, width=0.15, label=f'Year {year}', color=colors[i % len(colors)])

plt.xlabel("Blood Type")
plt.ylabel("Total Donations")
plt.title("Blood Donations by Blood Type for Each Year")
plt.xticks(x + 0.15, blood_types)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
blood_types = ['daily', 'blood_a', 'blood_b', 'blood_o', 'blood_ab']
df_blood = df[blood_types]

plt.figure(figsize=(14, 9))
sns.boxplot(data=df_blood)
plt.title("Boxplot of Blood Donations (Before Outlier Removal)")
plt.show()

# %%
blood_columns = ['daily', 'blood_a', 'blood_b', 'blood_o', 'blood_ab']
df_blood = df[blood_columns]

Q1 = df_blood.quantile(0.25)
Q3 = df_blood.quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df_blood_filtered = df_blood[~((df_blood < lower_bound) | (df_blood > upper_bound)).any(axis=1)]

# %%
df
# Out:
#            date  daily  blood_a  blood_b  blood_o  blood_ab  donations_new  \
# 0    2020-01-01   1646      419      444      663       120            350
# 1    2020-01-02    642      161      151      294        36            111
# 2    2020-01-03    787      196      209      338        44            149
# 3    2020-01-04   1301      342      347      529        83            274
# 4    2020-01-05   2345      604      609     1001       131            487
# ...         ...    ...      ...      ...      ...       ...            ...
# 1822 2024-12-27   1023      261      272      440        50            129
# 1823 2024-12-28   1798      475      501      724        98            248
# 1824 2024-12-29   2748      686      717     1192       153            295
# 1825 2024-12-30   1089      285      280      459        65            189
# 1826 2024-12-31   1702      414      468      731        89            336
#
#       donations_regular  donations_irregular       days  year
# ...

# %%
df_final = df.loc[df_blood_filtered.index]
df_final
# Out:
#            date  daily  blood_a  blood_b  blood_o  blood_ab  donations_new  \
# 0    2020-01-01   1646      419      444      663       120            350
# 1    2020-01-02    642      161      151      294        36            111
# 2    2020-01-03    787      196      209      338        44            149
# 3    2020-01-04   1301      342      347      529        83            274
# 4    2020-01-05   2345      604      609     1001       131            487
# ...         ...    ...      ...      ...      ...       ...            ...
# 1822 2024-12-27   1023      261      272      440        50            129
# 1823 2024-12-28   1798      475      501      724        98            248
# 1824 2024-12-29   2748      686      717     1192       153            295
# 1825 2024-12-30   1089      285      280      459        65            189
# 1826 2024-12-31   1702      414      468      731        89            336
#
#       donations_regular  donations_irregular       days  year
# ...

# %%
df_final.describe()
# Out:
#                                 date        daily      blood_a      blood_b  \
# count                           1739  1739.000000  1739.000000  1739.000000
# mean   2022-06-27 14:16:12.972973056  1404.880391   345.749281   381.112708
# min              2020-01-01 00:00:00     0.000000     0.000000     0.000000
# 25%              2021-04-01 12:00:00   983.000000   239.000000   266.000000
# 50%              2022-06-25 00:00:00  1295.000000   317.000000   356.000000
# 75%              2023-09-27 12:00:00  1699.500000   420.000000   470.000000
# max              2024-12-31 00:00:00  2921.000000   741.000000   805.000000
# std                              NaN   560.871483   141.841807   150.301362
#
#            blood_o     blood_ab  donations_new  donations_regular  \
# count  1739.000000  1739.000000    1739.000000        1739.000000
# mean    597.848189    80.113283     297.112708         857.201265
# min       0.000000     0.000000       0.000000           0.000000
# ...

# %%
plt.figure(figsize=(14, 9))
sns.boxplot(data=df_blood_filtered)
plt.title("Boxplot of Blood Donations (After Outlier Removal)")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_final['daily'], kde=True, bins=30)
plt.axvline(df_final['daily'].mean(), color='red', linestyle='dashed', label="Mean")
plt.axvline(df_final['daily'].median(), color='blue', linestyle='dashed', label="Median")
plt.legend()
plt.title("Distribution of Daily Donations")
plt.show()
# Why? Helps to visualize the distribution of blood donations (daily, new, regular, irregular) and detect skewness.

# %%
blood_types = ["blood_a", "blood_b", "blood_o", "blood_ab"]

plt.figure(figsize=(12, 8))

for i, blood in enumerate(blood_types, 1):
    plt.subplot(2, 2, i)
    sns.scatterplot(x=df_final["daily"], y=df_final[blood])
    plt.title(f"Daily Donations vs {blood.replace('_', ' ').title()}")
    plt.xlabel("Daily Donations")
    plt.ylabel(f"{blood.replace('_', ' ').title()} Donations")

plt.tight_layout()
plt.show()
# Why? To check the relationship between daily donations and a specific blood type.
# Insight: Identifies trends and potential patterns.

# %%
blood_sums = df_final[['blood_a', 'blood_b', 'blood_o', 'blood_ab']].sum()
plt.figure(figsize=(8, 8))
plt.pie(blood_sums, labels=blood_sums.index, autopct="%1.1f%%", colors=['red', 'blue', 'green', 'purple'])
plt.title("Proportion of Blood Donations by Type")
plt.show()
# Why? If you just want to compare the proportion of donations by blood type instead of trends.
# Best for: Showing the percentage of each blood type donated.
# Insight: Easily shows which blood type is donated the most and least.

# %%
# Exclude the "days" column before computing correlation
df_numeric = df_final.select_dtypes(include=["number"])

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df_numeric.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Blood Donation Features")
plt.show()
